# %%
import requests
import random
import time
import json
import urllib
import webbrowser
import io

token = '723294153:AAFKnUAet5yQVMEeXV9E9F4vJzPm91lZLlM'
url = 'https://api.telegram.org/bot'
gifKeywords = ['kielbasa', 'колбас', 'кильбас', 'сосис', 'sausage', 'hot dog', 'dodger', 'hotdog', 'хот дог', 'хотдог', 'хот-дог', 'френч-дог', 'френч дог']
recipeKeywords = ['рецепт', 'recipe', 'приготови', 'кулинар', 'cook']

class FoursquareCall:
    def __init__(self, location):
        self.location = location
        self.public = '3SJJZ1S5BBXYCSTPPRV2SQXB2VGOVFPRJMNTYFFWVNZX3BTU'
        self.url = 'https://api.foursquare.com/v2/venues/explore'
        
    def call(self):
        places=[]
        rad = 1000
        while not places:
            self.params = dict(
                          client_id = self.public,
                          client_secret = 'ADXHOUL2F3X05MJAHMOZUXH2R0FHBJWQSYSPRZYKEUEMZFRY',
                          radius = str(rad),
                          v='20180323',
                          ll = self.location,
                          query='колбаски',
                          limit = 10
                        )
            call = requests.get(url=self.url, params=self.params)
#            print(call.text)
            update = call.json()
            venues = update.get('response').get('groups')[0].get('items')
#            print(venues)
            if venues:
                for venue in venues:    
                    places.append(venue.get('venue').get('id'))
            rad +=1000
            print(places)
        return places
    
class KielbasaBot:
    def __init__(self, ready, token):
        self.ready = False
        self.token = token
        file = open('update_id.txt','r')
        self.offset = int(file.readline())
        file.close()
    
    def update(self):
        call = requests.get('https://api.telegram.org/bot723294153:AAFKnUAet5yQVMEeXV9E9F4vJzPm91lZLlM/getUpdates?offset='+str(self.offset))
        call = call.text.replace('true', 'True')
        call = call.replace('false', 'False')
        update = dict(eval(call)).get('result')
        if update:
            self.offset = int(update[-1].get('update_id'))+1
            file = open('update_id.txt','w')
            file.write(str(self.offset))
            file.close()
            print(update)
        return update
            
    def checkForEvents(self, update):
        for event in update:
            if 'photo' in event.get('message'):
                file_id = event.get('message').get('photo')[-1].get('file_id')
                call = requests.get('https://api.telegram.org/bot723294153:AAFKnUAet5yQVMEeXV9E9F4vJzPm91lZLlM/getFile?file_id='+file_id)
                get = call.json()
                img_url = 'https://api.telegram.org/file/bot723294153:AAFKnUAet5yQVMEeXV9E9F4vJzPm91lZLlM/'+get.get('result').get('file_path')
                image = requests.get(img_url)
                filePath = 'file.jpg'
                with open(filePath, 'wb') as f:
                    f.write(image.content)
                searchUrl = 'http://www.google.com/searchbyimage/upload'
                search = requests.post(searchUrl, files={'encoded_image': (filePath, open(filePath, 'rb')), 'image_content': ''},allow_redirects=False)
                fetchUrl = search.headers['Location']
                head = {
    'accept-language': 'en-US;q=0.8,en;q=0.7',
    'cookie': 'SEARCH_SAMESITE=CgQI1o0B; ANID=AHWqTUk-XCw0Ql59SxTRs2SHI0kcfabDdtS001r1A1jnTZ_xFF6J_54Sx1Y9G2oi; OTZ=5270909_44_44_123780_40_436260; S=billing-ui-v3=Fkq9bjm1wWBPH2UnJ4VjRuHfOCgMDI1O:billing-ui-v3-efe=Fkq9bjm1wWBPH2UnJ4VjRuHfOCgMDI1O; SID=tAcFfTSwY-nSpZvjK7Mt-QBpHrJxtyBH2Z4jVcb3Eg4d9jfvt2xXK5f5UaWLkJjZ89WRXQ.; __Secure-3PSID=tAcFfTSwY-nSpZvjK7Mt-QBpHrJxtyBH2Z4jVcb3Eg4d9jfv4D_DasuiqIwXZSJ5qQ9BRw.; HSID=Av_NpBb0Nkq3EflJ7; SSID=AJWECK-vRFbYiPFu8; APISID=xpFtFPKS3K2q6JTp/A11gexjFsQovDbstc; SAPISID=m2rKibYVBapKhzT_/AiZleEE0dUJTLFuTx; __Secure-HSID=Av_NpBb0Nkq3EflJ7; __Secure-SSID=AJWECK-vRFbYiPFu8; __Secure-APISID=xpFtFPKS3K2q6JTp/A11gexjFsQovDbstc; __Secure-3PAPISID=m2rKibYVBapKhzT_/AiZleEE0dUJTLFuTx; NID=196=NsBYtJGfqayUM3dIwXvWSUQOcOM68nwYm2AbI4bJQCPlLfyWWoRB3fr6WfneF1Xckb6xlShI3Dc-H8JVudtZpMyOETwvibVqUnCqD19g-FaFcBZKR_YDZhKO54E3veHNi4Km5yOPYMFIejKFB7-Y_cvTMD6or9hYE8u8nwPaHShfkK72uSgjYBkXAjumOUpmgfqgbIWiWZ51v3lwpt79_7V22Qu2RiOj9c47GwQvIpqRsQ4j_aNnybNlKZA4aZVACO0RYHuafl_ZXsqvH6cmJO8oTB9yPn4aXughhTbbBw; 1P_JAR=2020-1-27-13; SIDCC=AN0-TYtvQ0rI7L1_3ENYH1WNeeeN0Kw8D2PN_on87viBO67CoPo9CsWied0g21xLykzZ9RR-TqT3',
    'referer': 'https://www.google.com/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36',
}
                getcall = requests.get(fetchUrl, headers=head)
                filePath = 'file.html'
                with io.open(filePath, 'wb') as f:
                    f.write(getcall.content)

                with io.open(filePath, 'r', encoding='utf-8') as f:
                    for line in f:
                        if 'Possible related search:' in line: 
                            targetLine = 'Possible related search:'
                            newline = line[(line.find(targetLine))+80:(line.find(targetLine))+500]
                        if 'Запрос, который' in line:
                            targetLine = 'Запрос, который'
                            newline = line[(line.find(targetLine))+80:(line.find(targetLine))+500]
                result = newline[newline.find('>')+1:newline.find('<')].lower()
                print(result)
                for keyword in gifKeywords:
                    if keyword in result: 
                        kielbasabool = True
                        break
                    else: kielbasabool = False
                if kielbasabool: 
                    self.sendMessage(event, 'О да! Это изображение кильбасы!')
                else: self.sendMessage(event, 'Нет, это не кильбаса!')
                
            if 'location' in event.get('message'):
                self.sendMessage(event, 'Товарищ! Вот здесь подают колбаски!')
                self.sendMessage(event, 'https://ru.foursquare.com/v/'+self.getVenue(str(event.get('message').get('location').get('latitude'))+','+str(event.get('message').get('location').get('longitude'))))
                
            if 'text' in event.get('message'):
                print(event.get('message').get('from').get('username') + ': ' + event.get('message').get('text'))
                for keyword in gifKeywords:
                    if keyword in event.get('message').get('text').lower():
                        self.sendAnimation(event)
                for keyword in recipeKeywords:
                    if keyword in event.get('message').get('text').lower():
                        self.sendMessage(event, 'Ну, держи колбасный рецептик, дружок!')
                        self.sendMessage(event, self.getRecipe())
                        
            if 'new_chat_participant' in event.get('message'):
                if event.get('message').get('new_chat_participant').get('username') is 'KielbasaBot':
                    self.sendMessage(event, 'Доброе утро! Я Бот-колбасник! Попросите у меня колбасы или сосисок, и я вам заправлю!')
                    self.sendMessage(event, 'Ещё я могу делиться рецептами колбасных блюд! Просто попросите меня о рецепте!')
                    self.sendMessage(event, 'Если ты пришлёшь мне свою геолокацию, укажу тебе куда пойти отведать колбасок!')
                    self.sendMessage(event, 'А ещё я могу определять, что на картинках. Загрузи фоточку, и я скажу, кильбаса ли на ней.')
    
    def getRecipe(self):
        recipes = readFile('recipes.txt')
        targetRecipe = recipes[random.randint(0,len(recipes)-1)]
        return targetRecipe
    
    def getKielbasa(self):
        kielbasas = readFile('gifs.txt')
        targetKielbasa = kielbasas[random.randint(0,len(kielbasas)-1)]
        return targetKielbasa
    
    def getVenue(self, coords):
        forsquareCall = FoursquareCall(coords)
        venues = forsquareCall.call()
        targetVenue = venues[random.randint(0,len(venues)-1)]
        return targetVenue
    
    def getEndpoint(self, endpoint):
        self.endpoint = endpoint
        
    def buildSignature(self):
        self.url = url + self.token + self.endpoint
        
    def getChatId(self, event):
        chatId = str(event.get('message').get('chat').get('id'))
        return chatId
    
    def sendAnimation(self, event):
        self.getEndpoint('/sendAnimation')
        self.buildSignature()
        call = requests.post(self.url, data={'chat_id':self.getChatId(event),'animation':self.getKielbasa()})
        print(call.text)
    
    def sendMessage(self, event, text):
        self.getEndpoint('/sendMessage')
        self.buildSignature()
        call = requests.post(self.url, data={'chat_id':self.getChatId(event),'text':text})
        print(call.text)
        
def readFile(file):
    data = []
    openFile = open(file, 'r')
    for x in openFile: data.append(x[:-1])
    openFile.close()
    return data

if __name__ == '__main__':
    
    kielbasaBot = KielbasaBot(False, token)
    
    while True:
        try:
            time.sleep(1)
            kielbasaBot.checkForEvents(kielbasaBot.update())
        except (TypeError):
            print('TypeError exception occurred')
# Out:
# [{'message': {'photo': [{'file_unique_id': 'AQADu3PBDwAEFr4EAAE', 'width': 240, 'file_size': 10825, 'file_id': 'AgACAgIAAxkBAAIDS15O1gLIHOXsrhlJLByAyGrZOWAeAALRrTEb0HxwSuJ6fx-PhaqNu3PBDwAEAQADAgADbQADFr4EAAEYBA', 'height': 320}, {'file_unique_id': 'AQADu3PBDwAEF74EAAE', 'width': 600, 'file_size': 41417, 'file_id': 'AgACAgIAAxkBAAIDS15O1gLIHOXsrhlJLByAyGrZOWAeAALRrTEb0HxwSuJ6fx-PhaqNu3PBDwAEAQADAgADeAADF74EAAEYBA', 'height': 800}, {'file_unique_id': 'AQADu3PBDwAEFb4EAAE', 'width': 960, 'file_size': 64732, 'file_id': 'AgACAgIAAxkBAAIDS15O1gLIHOXsrhlJLByAyGrZOWAeAALRrTEb0HxwSuJ6fx-PhaqNu3PBDwAEAQADAgADeQADFb4EAAEYBA', 'height': 1280}], 'chat': {'type': 'private', 'username': 'Bpy6na', 'id': 228334796, 'last_name': 'Yushkov', 'first_name': 'Alexander'}, 'date': 1582224898, 'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'en', 'is_bot': False}, 'message_id': 843}, 'update_id': 414362277}]
# machine
# {"ok":true,"result":{"message_id":844,"from":{"id":723294153,"is_bot":true,"first_name":"\u0411\u043e\u0442-\u043a\u043e\u043b\u0431\u0430\u0441\u043d\u0438\u043a","username":"KielbasaBot"},"chat":{"id":228334796,"first_name":"Alexander","last_name":"Yushkov","username":"Bpy6na","type":"private"},"date":1582224905,"text":"\u041d\u0435\u0442, \u044d\u0442\u043e \u043d\u0435 \u043a\u0438\u043b\u044c\u0431\u0430\u0441\u0430!"}}
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'апдейт. Починил неработающий поиск заведений и немножко улучшил алгоритм поиска. Периодически теперь даже может выдавать рандомные места', 'date': 1582224979, 'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13287}, 'update_id': 414362278}]
# Bpy6na: апдейт. Починил неработающий поиск заведений и немножко улучшил алгоритм поиска. Периодически теперь даже может выдавать рандомные места
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'Совсем рандомные, не взирая на континент?', 'date': 1582225010, 'from': {'first_name': 'Немой', 'last_name': 'Укроп', 'id': 299891019, 'username': 'Paralitiq', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13288}, 'update_id': 414362279}]
# Paralitiq: Совсем рандомные, не взирая на континент?
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'не, он всё ещё ищет по радию,  но выдает рандомное из найденных, а не как раньше', 'date': 1582225038, 'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13289}, 'update_id': 414362280}]
# Bpy6na: не, он всё ещё ищет по радию,  но выдает рандомное из найденных, а не как раньше
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'и гораздо больше заведений находит кстати, и более релевантных', 'date': 1582225058, 'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13290}, 'update_id': 414362281}]
# Bpy6na: и гораздо больше заведений находит кстати, и более релевантных
# [{'message': {'location': {'longitude': 30.460753, 'latitude': 59.902201}, 'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'date': 1582225081, 'from': {'first_name': 'Немой', 'last_name': 'Укроп', 'id': 299891019, 'username': 'Paralitiq', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13291}, 'update_id': 414362282}]
# {"ok":true,"result":{"message_id":13292,"from":{"id":723294153,"is_bot":true,"first_name":"\u0411\u043e\u0442-\u043a\u043e\u043b\u0431\u0430\u0441\u043d\u0438\u043a","username":"KielbasaBot"},"chat":{"id":-1001315328411,"title":"\u041e\u0447\u0435\u043d\u044c \u043e\u0442\u043b\u0438\u0447\u043d\u044b\u0439 \u0438\u0433\u043e\u0440\u044c","type":"supergroup"},"date":1582225082,"text":"\u0422\u043e\u0432\u0430\u0440\u0438\u0449! \u0412\u043e\u0442 \u0437\u0434\u0435\u0441\u044c \u043f\u043e\u0434\u0430\u044e\u0442 \u043a\u043e\u043b\u0431\u0430\u0441\u043a\u0438!"}}
# []
# ['4e2c7bc47d8b7deda6dbd4f0', '4ca24f09d695199c84e73be7']
# {"ok":true,"result":{"message_id":13293,"from":{"id":723294153,"is_bot":true,"first_name":"\u0411\u043e\u0442-\u043a\u043e\u043b\u0431\u0430\u0441\u043d\u0438\u043a","username":"KielbasaBot"},"chat":{"id":-1001315328411,"title":"\u041e\u0447\u0435\u043d\u044c \u043e\u0442\u043b\u0438\u0447\u043d\u044b\u0439 \u0438\u0433\u043e\u0440\u044c","type":"supergroup"},"date":1582225083,"text":"https://ru.foursquare.com/v/4e2c7bc47d8b7deda6dbd4f0","entities":[{"offset":0,"length":52,"type":"url"}]}}
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'Бля, мюнхель срака :/', 'date': 1582225107, 'from': {'first_name': 'Немой', 'last_name': 'Укроп', 'id': 299891019, 'username': 'Paralitiq', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13294}, 'update_id': 414362283}]
# Paralitiq: Бля, мюнхель срака :/
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'одно из двух результов с твоей точки', 'date': 1582225124, 'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13295}, 'update_id': 414362284}]
# Bpy6na: одно из двух результов с твоей точки
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'А второе что?', 'date': 1582225132, 'from': {'first_name': 'Немой', 'last_name': 'Укроп', 'id': 299891019, 'username': 'Paralitiq', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13296}, 'update_id': 414362285}]
# Paralitiq: А второе что?
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'хз я только ID в логе вижу)', 'date': 1582225142, 'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13297}, 'update_id': 414362286}]
# Bpy6na: хз я только ID в логе вижу)
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'ща', 'date': 1582225143, 'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13298}, 'update_id': 414362287}]
# Bpy6na: ща
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'а', 'date': 1582225165, 'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13299}, 'update_id': 414362288}]
# Bpy6na: а
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'второе по классике же', 'date': 1582225169, 'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13300}, 'update_id': 414362289}]
# Bpy6na: второе по классике же
# [{'message': {'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'ru', 'is_bot': False}, 'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'https://ru.foursquare.com/v/olymp/4ca24f09d695199c84e73be7', 'date': 1582225170, 'message_id': 13301, 'entities': [{'type': 'url', 'offset': 0, 'length': 58}]}, 'update_id': 414362290}]
# Bpy6na: https://ru.foursquare.com/v/olymp/4ca24f09d695199c84e73be7
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'Оооо, мои любимые колбаски', 'date': 1582225185, 'from': {'first_name': 'Немой', 'last_name': 'Укроп', 'id': 299891019, 'username': 'Paralitiq', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13302}, 'update_id': 414362291}]
# Paralitiq: Оооо, мои любимые колбаски
# {"ok":true,"result":{"message_id":13303,"from":{"id":723294153,"is_bot":true,"first_name":"\u0411\u043e\u0442-\u043a\u043e\u043b\u0431\u0430\u0441\u043d\u0438\u043a","username":"KielbasaBot"},"chat":{"id":-1001315328411,"title":"\u041e\u0447\u0435\u043d\u044c \u043e\u0442\u043b\u0438\u0447\u043d\u044b\u0439 \u0438\u0433\u043e\u0440\u044c","type":"supergroup"},"date":1582225188,"animation":{"file_name":"giphy.mp4","mime_type":"video/mp4","duration":4,"width":480,"height":268,"thumb":{"file_id":"AAMCBAADHQROZlGbAAIz915O1yShnesTCIrRauypMdgJCLxhAAK2AQACjB8FUSgtKoYHpA5PitiyGwAEAQAHbQADOo4AAhgE","file_unique_id":"AQADitiyGwAEOo4AAg","file_size":15793,"width":320,"height":179},"file_id":"CgACAgQAAx0ETmZRmwACM_deTtckoZ3rEwiK0WrsqTHYCQi8YQACtgEAAowfBVEoLSqGB6QOTxgE","file_unique_id":"AgADtgEAAowfBVE","file_size":430817},"document":{"file_name":"giphy.mp4","mime_type":"video/mp4","thumb":{"file_id":"AAMCBAADHQROZlGbAAIz915O1yShnesTCIrRauypMdgJCLxhAAK2AQACjB8FUSgtKoYHpA5PitiyGwAEAQAHbQADOo4AAhgE","file_unique_id":"AQADitiyGwAEOo4AAg","file_size":15793,"width":320,"height":179},"file_id":"CgACAgQAAx0ETmZRmwACM_deTtckoZ3rEwiK0WrsqTHYCQi8YQACtgEAAowfBVEoLSqGB6QOTxgE","file_unique_id":"AgADtgEAAowfBVE","file_size":430817}}}
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'Пидр', 'date': 1582225191, 'from': {'first_name': 'Немой', 'last_name': 'Укроп', 'id': 299891019, 'username': 'Paralitiq', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13304}, 'update_id': 414362292}]
# Paralitiq: Пидр
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'теперь пойдет на износ. Посмотрим сколько будет аптайм у бота на майкрософте', 'date': 1582225287, 'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13305}, 'update_id': 414362293}]
# Bpy6na: теперь пойдет на износ. Посмотрим сколько будет аптайм у бота на майкрософте
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'А тыкать его надо?', 'date': 1582225311, 'from': {'first_name': 'Немой', 'last_name': 'Укроп', 'id': 299891019, 'username': 'Paralitiq', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13306}, 'update_id': 414362294}]
# Paralitiq: А тыкать его надо?
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'Или пусть так висит', 'date': 1582225318, 'from': {'first_name': 'Немой', 'last_name': 'Укроп', 'id': 299891019, 'username': 'Paralitiq', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13307}, 'update_id': 414362295}]
# Paralitiq: Или пусть так висит
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'не, не обязательно', 'date': 1582225323, 'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13308}, 'update_id': 414362296}]
# Bpy6na: не, не обязательно
# [{'message': {'chat': {'id': -1001315328411, 'type': 'supergroup', 'title': 'Очень отличный игорь'}, 'text': 'просто висит и всё', 'date': 1582225328, 'from': {'first_name': 'Alexander', 'last_name': 'Yushkov', 'id': 228334796, 'username': 'Bpy6na', 'language_code': 'ru', 'is_bot': False}, 'message_id': 13309}, 'update_id': 414362297}]
# Bpy6na: просто висит и всё
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-a08703181df9> in <module>()
#     181         try:
#     182             time.sleep(1)
# --> 183             kielbasaBot.checkForEvents(kielbasaBot.update())
#     184         except (TypeError):
#     185             print('TypeError exception occurred')
#
# <ipython-input-27-a08703181df9> in update(self)
#      52
#      53     def update(self):
# ---> 54         call = requests.get('https://api.telegram.org/bot723294153:AAFKnUAet5yQVMEeXV9E9F4vJzPm91lZLlM/getUpdates?offset='+str(self.offset))
#      55         call = call.text.replace('true', 'True')
#      56         call = call.replace('false', 'False')
#
# ~/anaconda3_420/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3_420/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3_420/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# ~/anaconda3_420/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# ~/anaconda3_420/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# ~/anaconda3_420/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     592             is_new_proxy_conn = self.proxy is not None and not getattr(conn, 'sock', None)
#     593             if is_new_proxy_conn:
# --> 594                 self._prepare_proxy(conn)
#     595
#     596             # Make the request on the httplib connection object.
#
# ~/anaconda3_420/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#     808             set_tunnel(self.host, self.port, self.proxy_headers)
#     809
# --> 810         conn.connect()
#     811
#     812     def _new_conn(self):
#
# ~/anaconda3_420/lib/python3.5/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     324             ca_cert_dir=self.ca_cert_dir,
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#     328         if self.assert_fingerprint:
#
# ~/anaconda3_420/lib/python3.5/site-packages/requests/packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     323         context.load_cert_chain(certfile, keyfile)
#     324     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 325         return context.wrap_socket(sock, server_hostname=server_hostname)
#     326
#     327     warnings.warn(
#
# ~/anaconda3_420/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     436         while True:
#     437             try:
# --> 438                 cnx.do_handshake()
#     439             except OpenSSL.SSL.WantReadError:
#     440                 rd = util.wait_for_read(sock, sock.gettimeout())
#
# ~/anaconda3_420/lib/python3.5/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1713         :return: None.
#    1714         """
# -> 1715         result = _lib.SSL_do_handshake(self._ssl)
#    1716         self._raise_ssl_error(self._ssl, result)
#    1717
#
# KeyboardInterrupt:
